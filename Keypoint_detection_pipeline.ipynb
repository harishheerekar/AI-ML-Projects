# %% [markdown]
# <a href="https://colab.research.google.com/github/harishheerekar/AI-ML-Projects/blob/main/Keypoint_detection_pipeline.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import matplotlib.pyplot as plt

# %%
image_path = ('/content/GettyImages-2195074919.jpg')
image = cv2.imread(image_path)

# %%
#convert to grayscale
if image is None:
    print("Error: Could not load image. Please check the image path.")
else:
    gray_image= cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    #show the image
    plt.imshow(gray_image, cmap='gray')
    plt.title('Grayscale Image')
    plt.axis('off')
    plt.show()

# %%
# Step 3: Initialize ORB Detector
orb = cv2.ORB_create(nfeatures=1000)

# %%
# Step 4: Detect Keypoints and Compute Descriptors
keypoints, descriptors = orb.detectAndCompute(image, None)

# %%
# Step 5: Draw Keypoints on Image
keypoint_image = cv2.drawKeypoints(image, keypoints, None, color=(0, 255, 0), flags=0)

# %%
# Step 6: Display Image
plt.figure(figsize=(12, 8))
plt.imshow(cv2.cvtColor(keypoint_image, cv2.COLOR_BGR2RGB))
plt.title("ORB Keypoints")
plt.axis("off")
plt.show()

# %%
# Optional: Print Descriptor Info
print(f"Number of keypoints detected: {len(keypoints)}")
print(f"Descriptor shape: {descriptors.shape}")
# Out:
# Number of keypoints detected: 1000
# Descriptor shape: (1000, 32)

# %%
brisk = cv2.BRISK_create()

# %%
# Step 4: Detect Keypoints and Compute Descriptors
keypoints, descriptors = orb.detectAndCompute(image, None)

# %%
brisk_output = cv2.drawKeypoints(image, keypoints, None, color=(0, 255, 0),
                                 flags=cv2.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS)

# %%
# Step 6: Display Image
plt.figure(figsize=(12, 8))
plt.imshow(cv2.cvtColor(keypoint_image, cv2.COLOR_BGR2RGB))
plt.title("BRISK Keypoints")
plt.axis("off")
plt.show()

# %%
keypoints, descriptors = brisk.detectAndCompute(image, None)

# %%
# Optional: Print Descriptor Info
print(f"Number of keypoints detected: {len(keypoints)}")
print(f"Descriptor shape: {descriptors.shape}")
# Out:
# Number of keypoints detected: 1571
# Descriptor shape: (1571, 64)

# %%
# Step 3: Initialize AKAZE Detector
akaze = cv2.AKAZE_create()

# %%
# Step 4: Detect Keypoints and Compute Descriptors
keypoints, descriptors = akaze.detectAndCompute(image, None)

# %%
# Step 5: Draw Keypoints
output_image = cv2.drawKeypoints(image, keypoints, None,
                                 color=(0, 255, 0),
                                 flags=cv2.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS)

# %%
# Step 4: Detect Keypoints and Compute Descriptors
keypoints, descriptors = orb.detectAndCompute(image, None)

# %%
# Step 5: Draw Keypoints on Image
keypoint_image = cv2.drawKeypoints(image, keypoints, None, color=(0, 255, 0), flags=0)

# %%
# Step 6: Display the Image
plt.figure(figsize=(12, 8))
plt.imshow(cv2.cvtColor(output_image, cv2.COLOR_BGR2RGB))
plt.title("AKAZE Feature Keypoints")
plt.axis("off")
plt.show()

# %%
# Optional: Print Descriptor Info
print(f"Number of keypoints detected: {len(keypoints)}")
print(f"Descriptor shape: {descriptors.shape}")
# Out:
# Number of keypoints detected: 1000
# Descriptor shape: (1000, 32)

# %%
#convert to grayscale
gray_image= cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
#show the image
plt.imshow(gray_image, cmap='gray')
